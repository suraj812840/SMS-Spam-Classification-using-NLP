# %%
import numpy as np
import pandas as pd

# %%
sms=pd.read_csv('/content/Spam_Dataset.csv')

# %%
sms
# Out:
#   label                                           features
# 0   ham                      Hey, how are you doing today?
# 1   ham                    Can we meet for lunch tomorrow?
# 2  spam  WINNER! You've won a free holiday! Call now to...
# 3   ham               Just got back from the grocery store
# 4   ham              What's up? Are you free this weekend?
# 5  spam  Urgent: Your credit card is about to expire. C...
# 6   ham                          See you later, gotta run!
# 7  spam             Free mobile phone! Text 'YES' to 12345
# 8   ham              Did you see the new movie last night?
# 9  spam  Exclusive offer: Get 50% off on your next purc...

# %%
s='Hey, how are you doing today?'
s.split()
# Out:
# ['Hey,', 'how', 'are', 'you', 'doing', 'today?']

# %%
import pandas as pd
import nltk

# %%
from nltk.tokenize import word_tokenize
import nltk
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# True

# %%
word_tokenize(s) # isko toekization kehte hai.. har ek cheez ko separate krta hai ...
# Out:
# ['Hey', ',', 'how', 'are', 'you', 'doing', 'today', '?']

# %%
nltk.download('punkt') # punkt ek package hai nltk ke andar..
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
words=word_tokenize(s)
print(words)
# Out:
# ['Hey', ',', 'how', 'are', 'you', 'doing', 'today', '?']

# %%
ignore_characters=['?','!','.',',','%']
words1=[w.lower() for w in words if w not in ignore_characters]
print(words1)
# Out:
# ['hey', 'how', 'are', 'you', 'doing', 'today']

# %%
s1="Exclusive offer: Get 50% off on your next purc.."
s1.split()
# Out:
# ['Exclusive', 'offer:', 'Get', '50%', 'off', 'on', 'your', 'next', 'purc..']

# %%
words=word_tokenize(s1)
print(words)
# Out:
# ['Exclusive', 'offer', ':', 'Get', '50', '%', 'off', 'on', 'your', 'next', 'purc', '..']

# %%
ignore_characters=['?','!','.',',','%',':','..']
words1=[w.lower() for w in words if w not in ignore_characters]
print(words1)
# Out:
# ['exclusive', 'offer', 'get', '50', 'off', 'on', 'your', 'next', 'purc']

# %%
words2=[w for w in words1 if not w.isdigit()]
print(words2)
# Out:
# ['exclusive', 'offer', 'get', 'off', 'on', 'your', 'next', 'purc']

# %%
#stopwords
from nltk.corpus import stopwords
import nltk

# Download the 'stopwords' dataset
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
stop_words=stopwords.words('english')
print(stop_words)
# Out:
# ['a', 'about', 'above', 'after', 'again', 'against', 'ain', 'all', 'am', 'an', 'and', 'any', 'are', 'aren', "aren't", 'as', 'at', 'be', 'because', 'been', 'before', 'being', 'below', 'between', 'both', 'but', 'by', 'can', 'couldn', "couldn't", 'd', 'did', 'didn', "didn't", 'do', 'does', 'doesn', "doesn't", 'doing', 'don', "don't", 'down', 'during', 'each', 'few', 'for', 'from', 'further', 'had', 'hadn', "hadn't", 'has', 'hasn', "hasn't", 'have', 'haven', "haven't", 'having', 'he', "he'd", "he'll", 'her', 'here', 'hers', 'herself', "he's", 'him', 'himself', 'his', 'how', 'i', "i'd", 'if', "i'll", "i'm", 'in', 'into', 'is', 'isn', "isn't", 'it', "it'd", "it'll", "it's", 'its', 'itself', "i've", 'just', 'll', 'm', 'ma', 'me', 'mightn', "mightn't", 'more', 'most', 'mustn', "mustn't", 'my', 'myself', 'needn', "needn't", 'no', 'nor', 'not', 'now', 'o', 'of', 'off', 'on', 'once', 'only', 'or', 'other', 'our', 'ours', 'ourselves', 'out', 'over', 'own', 're', 's', 'same', 'shan', "shan't", 's
# ...

# %%
stop_words[:10]
# Out:
# ['a', 'about', 'above', 'after', 'again', 'against', 'ain', 'all', 'am', 'an']

# %%
words3=[w for w in words2 if w not in stop_words]
print(words3)
# Out:
# ['exclusive', 'offer', 'get', 'next', 'purc']

# %% [markdown]
# #stemming and lemmatization

# %%
from nltk.stem import PorterStemmer,SnowballStemmer
from nltk.stem import WordNetLemmatizer
import nltk
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
stemming=PorterStemmer()
lemmatize=WordNetLemmatizer()

# %%
[stemming.stem(w) for w in ['RUNNing','runs','indians','beautiful','aggressive','comfotable','went']]
# Out:
# ['run', 'run', 'indian', 'beauti', 'aggress', 'comfot', 'went']

# %%
[lemmatize.lemmatize(w,pos='v') for w in ['RUNNing','runs','indians','beautiful','aggressive','comfotable','went']]
# Out:
# ['RUNNing', 'run', 'indians', 'beautiful', 'aggressive', 'comfotable', 'go']

# %%
words=[]
for w in sms.features:
  t=word_tokenize(w)
  words1=[w.lower() for w in t if w not in ignore_characters]
  words2=[w for w in words1 if not w.isdigit()]
  words3=[w for w in words2 if w not in stop_words]
  words.extend(words3)
words
# Out:
# ['hey',
#  'today',
#  'meet',
#  'lunch',
#  'tomorrow',
#  'winner',
#  "'ve",
#  'free',
#  'holiday',
#  'call',
#  'claim',
#  'got',
#  'back',
#  'grocery',
#  'store',
#  "'s",
#  'free',
#  'weekend',
#  'urgent',
#  'credit',
#  'card',
#  'expire',
#  'click',
#  'update',
#  'see',
#  'later',
#  'got',
#  'ta',
#  'run',
#  'free',
#  'mobile',
#  'phone',
#  'text',
#  "'yes",
#  "'",
#  'see',
#  'new',
#  'movie',
#  'last',
#  'night',
#  'exclusive',
#  'offer',
#  'get',
#  'next',
#  'purchase']

# %%
print(words)
# Out:
# ['hey', 'today', 'meet', 'lunch', 'tomorrow', 'winner', "'ve", 'free', 'holiday', 'call', 'claim', 'got', 'back', 'grocery', 'store', "'s", 'free', 'weekend', 'urgent', 'credit', 'card', 'expire', 'click', 'update', 'see', 'later', 'got', 'ta', 'run', 'free', 'mobile', 'phone', 'text', "'yes", "'", 'see', 'new', 'movie', 'last', 'night', 'exclusive', 'offer', 'get', 'next', 'purchase']

# %%
len(words)
# Out:
# 45

# %%
words=[]
for w in sms.features:
  t=word_tokenize(w)
  words1=[w.lower() for w in t if w not in ignore_characters]
  words2=[w for w in words1 if not w.isdigit()]
  words3=[[lemmatize.lemmatize(w,pos='v') for w in words2 if w not in stop_words]]
  words.extend(words3)
words
# Out:
# [['hey', 'today'],
#  ['meet', 'lunch', 'tomorrow'],
#  ['winner', "'ve", 'free', 'holiday', 'call', 'claim'],
#  ['get', 'back', 'grocery', 'store'],
#  ["'s", 'free', 'weekend'],
#  ['urgent', 'credit', 'card', 'expire', 'click', 'update'],
#  ['see', 'later', 'get', 'ta', 'run'],
#  ['free', 'mobile', 'phone', 'text', "'yes", "'"],
#  ['see', 'new', 'movie', 'last', 'night'],
#  ['exclusive', 'offer', 'get', 'next', 'purchase']]

# %%
len(words)
# Out:
# 10

# %%
words=[]
for w in sms.features:
  t=word_tokenize(w)
  words1=[w.lower() for w in t if w not in ignore_characters]
  words2=[w for w in words1 if not w.isdigit()]
  words3=[[stemming.stem(w) for w in words2 if w not in stop_words]]
  words.extend(words3)
words
# Out:
# [['hey', 'today'],
#  ['meet', 'lunch', 'tomorrow'],
#  ['winner', "'ve", 'free', 'holiday', 'call', 'claim'],
#  ['got', 'back', 'groceri', 'store'],
#  ["'s", 'free', 'weekend'],
#  ['urgent', 'credit', 'card', 'expir', 'click', 'updat'],
#  ['see', 'later', 'got', 'ta', 'run'],
#  ['free', 'mobil', 'phone', 'text', "'ye", "'"],
#  ['see', 'new', 'movi', 'last', 'night'],
#  ['exclus', 'offer', 'get', 'next', 'purchas']]

# %%
from nltk.stem.snowball import SnowballStemmer # import the SnowballStemmer class from nltk.stem.snowball

stemming = SnowballStemmer("english") # create an instance of SnowballStemmer for English
#EnglishStemmer() # You likely meant to call stemmer.stem() on a word

# %%
words=[]
for w in sms.features:
  t=word_tokenize(w)
  words1=[w.lower() for w in t if w not in ignore_characters]
  words2=[w for w in words1 if not w.isdigit()]
  words3=[w for w in words2 if w not in stop_words]
  words.extend(words3)
clean_words=sorted(set(words))
clean_words
# Out:
# ["'",
#  "'s",
#  "'ve",
#  "'yes",
#  'back',
#  'call',
#  'card',
#  'claim',
#  'click',
#  'credit',
#  'exclusive',
#  'expire',
#  'free',
#  'get',
#  'got',
#  'grocery',
#  'hey',
#  'holiday',
#  'last',
#  'later',
#  'lunch',
#  'meet',
#  'mobile',
#  'movie',
#  'new',
#  'next',
#  'night',
#  'offer',
#  'phone',
#  'purchase',
#  'run',
#  'see',
#  'store',
#  'ta',
#  'text',
#  'today',
#  'tomorrow',
#  'update',
#  'urgent',
#  'weekend',
#  'winner']

# %%
len(words)
# Out:
# 45
